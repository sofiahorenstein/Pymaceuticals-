# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "../Pymaceuticals-/mouse_drug_data.csv"
clinical_trial_data_to_load = "../Pymaceuticals-/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_drug_data = "../Pymaceuticals-/mouse_drug_data.csv"
mouse_data = pd.read_csv(mouse_drug_data)
mouse_data

clinicaltrial_data = "../Pymaceuticals-/clinicaltrial_data.csv"
clinical_data = pd.read_csv(clinicaltrial_data)
clinical_data

# Combine the data into a single dataset
mouse_clinical = pd.merge(mouse_data, clinical_data)
# Display the data table for preview
mouse_clinical
# Out:
#      Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        f234  Stelasyn          0           45.000000                 0
# 1        f234  Stelasyn          5           47.313491                 0
# 2        f234  Stelasyn         10           47.904324                 0
# 3        f234  Stelasyn         15           48.735197                 1
# 4        f234  Stelasyn         20           51.112713                 2
# 5        f234  Stelasyn         25           52.178602                 2
# 6        f234  Stelasyn         30           56.873817                 2
# 7        f234  Stelasyn         35           57.748758                 2
# 8        x402  Stelasyn          0           45.000000                 0
# 9        x402  Stelasyn          5           46.327570                 1
# 10       x402  Stelasyn         10           46.886962                 1
# 11       x402  Stelasyn         15           49.119948                 1
# ...

# %%
mouse_clinical_group2 = mouse_clinical.groupby(["Drug", "Timepoint"])
mean_tumor2 = pd.DataFrame(mouse_clinical_group2.mean()["Tumor Volume (mm3)"])
new_mean_tumor = mean_tumor2.reset_index()
new_mean_tumor
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0           45.000000
# 1   Capomulin          5           44.266086
# 2   Capomulin         10           43.084291
# 3   Capomulin         15           42.064317
# 4   Capomulin         20           40.716325
# 5   Capomulin         25           39.939528
# 6   Capomulin         30           38.769339
# 7   Capomulin         35           37.816839
# 8   Capomulin         40           36.958001
# 9   Capomulin         45           36.236114
# 10   Ceftamin          0           45.000000
# 11   Ceftamin          5           46.503051
# 12   Ceftamin         10           48.285125
# 13   Ceftamin         15           50.094055
# 14   Ceftamin         20           52.157049
# 15   Ceftamin         25           54.287674
# 16   Ceftamin         30           56.769517
# 17   Ceftamin         35           58.827548
# 18   Ceftamin         40           61.467895
# 19   Ceftamin         45           64.132421
# ...

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
mouse_clinical_group = mouse_clinical.groupby(["Drug","Timepoint"])
mouse_clinical_group["Tumor Volume (mm3)"].mean()
# Convert to DataFrame
mean_tumor = pd.DataFrame(mouse_clinical_group["Tumor Volume (mm3)"].mean())
# Preview DataFrame
mean_tumor
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325
#           25                  39.939528
#           30                  38.769339
#           35                  37.816839
#           40                  36.958001
#           45                  36.236114
# Ceftamin  0                   45.000000
#           5                   46.503051
#           10                  48.285125
#           15                  50.094055
#           20                  52.157049
#           25                  54.287674
#           30                  56.769517
#           35                  58.827548
#           40                  61.467895
#           45                  64.132421
# Infubinol 0                   45.000000
#           5                   47.062001
# ...

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
#standard_errors = [sem(s) for s in mean_tumor]
mouse_clinical_group2["Tumor Volume (mm3)"].sem()

# Convert to DataFrame
standard_err = pd.DataFrame(mouse_clinical_group2["Tumor Volume (mm3)"].sem())
# Preview DataFrame
standard_err_df = standard_err.reset_index()

# %%
# Minor Data Munging to Re-Format the Data Frames
new_mean_tumor_pivot = new_mean_tumor.pivot(index="Timepoint", columns="Drug")["Tumor Volume (mm3)"]
standard_err_pivot = standard_err_df.pivot(index="Timepoint", columns="Drug")["Tumor Volume (mm3)"]
new_mean_tumor_pivot

# Preview that Reformatting worked
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
new_mean_tumor_pivot = new_mean_tumor.pivot(index="Timepoint", columns="Drug")["Tumor Volume (mm3)"]
standard_err_pivot = standard_err_df.pivot(index="Timepoint", columns="Drug")["Tumor Volume (mm3)"]
standard_err_pivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
ax = new_mean_tumor_pivot.plot(xticks=new_mean_tumor_pivot.index)
ylab = ax.set_ylabel("Tumor Volume (mm3)")

# %%
# Generate the Plot (with Error Bars)

fig, ax = plt.subplots()

x_axis = np.arange(0, len(new_mean_tumor_pivot), 1)

ax.errorbar(np.arange(0, len(new_mean_tumor_pivot), means, yerr=sem, fmt="o", color="b",
            alpha=0.5, label="Mean of Tumor Volume")



ax.set_xlabel("Timepoint")
ax.set_ylabel("mean of Tumor Volume")

plt.legend(loc="best", fontsize="small", fancybox=True)

plt.show()

# Save the Figure
# Out:
#   File "<ipython-input-10-8d928862fede>", line 12
#     ax.set_xlabel("Timepoint")
#      ^
# SyntaxError: invalid syntax

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
#mouse_clinical_group["Metastatic Sites"].mean()

# Convert to DataFrame
#mean_met_df = pd.DataFrame(mouse_clinical_group["Metastatic Sites"].mean())
#mean_met_df
# Preview DataFramemouse_clinical_group2 = mouse_clinical.groupby(["Drug", "Timepoint"])


mouse_clinical_group3 = mouse_clinical.groupby(["Drug", "Timepoint"])
mean_met = pd.DataFrame(mouse_clinical_group3["Metastatic Sites"].mean())
new_mean_met = mean_met.reset_index()
new_mean_met
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.160000
# 2   Capomulin         10          0.320000
# 3   Capomulin         15          0.375000
# 4   Capomulin         20          0.652174
# 5   Capomulin         25          0.818182
# 6   Capomulin         30          1.090909
# 7   Capomulin         35          1.181818
# 8   Capomulin         40          1.380952
# 9   Capomulin         45          1.476190
# 10   Ceftamin          0          0.000000
# 11   Ceftamin          5          0.380952
# 12   Ceftamin         10          0.600000
# 13   Ceftamin         15          0.789474
# 14   Ceftamin         20          1.111111
# 15   Ceftamin         25          1.500000
# 16   Ceftamin         30          1.937500
# 17   Ceftamin         35          2.071429
# 18   Ceftamin         40          2.357143
# 19   Ceftamin         45          2.692308
# 20  Infubinol          0          0.000000
# ...

# %%
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
#mouse_clinical_group["Metastatic Sites"].sem()
# Convert to DataFrame
#stand_dev_met = pd.DataFrame(mouse_clinical_group["Metastatic Sites"].sem())
# Preview DataFrame
#stand_dev_met

mouse_clinical_group3["Metastatic Sites"].sem()

# Convert to DataFrame
standard_err_met = pd.DataFrame(mouse_clinical_group3["Metastatic Sites"].sem())
# Preview DataFrame
standard_err_met_df = standard_err_met.reset_index()

standard_err_met_df
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.074833
# 2   Capomulin         10          0.125433
# 3   Capomulin         15          0.132048
# 4   Capomulin         20          0.161621
# 5   Capomulin         25          0.181818
# 6   Capomulin         30          0.172944
# 7   Capomulin         35          0.169496
# 8   Capomulin         40          0.175610
# 9   Capomulin         45          0.202591
# 10   Ceftamin          0          0.000000
# 11   Ceftamin          5          0.108588
# 12   Ceftamin         10          0.152177
# 13   Ceftamin         15          0.180625
# 14   Ceftamin         20          0.241034
# 15   Ceftamin         25          0.258831
# 16   Ceftamin         30          0.249479
# 17   Ceftamin         35          0.266526
# 18   Ceftamin         40          0.289128
# 19   Ceftamin         45          0.286101
# 20  Infubinol          0          0.000000
# ...

# %%
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames
new_mean_met_pivot = new_mean_met.pivot(index="Timepoint", columns="Drug")["Metastatic Sites"]
standard_err_met_pivot = standard_err_met_df.pivot(index="Timepoint", columns="Drug")["Metastatic Sites"]
#standard_err_met_pivot
# Preview that Reformatting worked
new_mean_met_pivot

standard_err_met_pivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
# 25          0.181818  0.258831   0.265753  0.288275  0.185240  0.263888
# 30          0.172944  0.249479   0.227823  0.347467  0.266667  0.300264
# 35          0.169496  0.266526   0.224733  0.361418  0.330464  0.341412
# 40          0.175610  0.289128   0.314466  0.315725  0.321702  0.297294
# 45          0.202591  0.286101   0.309320  0.278722  0.351104  0.304240
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# Generate the Plot (with Error Bars)

# Save the Figure

# Show the Figure

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
counts = mouse_clinical_group3(["Timepoint", "Drug"]).value_counts()
counts


mouse_count = mouse_clinical_group3["Mouse ID"].value_counts()
mouse_count_df = pd.DataFrame(mouse_count.reset_index(name="Mouse Count"))



mouse_count_df.groupby(["Timepoint", "Mouse Count"])
mouse_count_df["Timepoint"].value_counts()

#size().rename("Mouse Count").reset_index())

# Convert to DataFrame

# Preview DataFrame
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-da5654eee353> in <module>
#       1 # Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
# ----> 2 counts = mouse_clinical_group3(["Timepoint", "Drug"]).value_counts()
#       3 counts
#       4
#       5
#
# TypeError: 'DataFrameGroupBy' object is not callable

# %%
# Out:
#         Drug  Timepoint  Mouse Count
# 0  Capomulin          0           25
# 1  Capomulin          5           25
# 2  Capomulin         10           25
# 3  Capomulin         15           24
# 4  Capomulin         20           23

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview the Data Frame

# %%
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17

# %%
# Generate the Plot (Accounting for percentages)

# Save the Figure

# Show the Figure
plt.show()

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

# Display the data to confirm

# %%
# Out:
# Drug
# Capomulin   -19.475303
# Ceftamin     42.516492
# Infubinol    46.123472
# Ketapril     57.028795
# Naftisol     53.923347
# Placebo      51.297960
# Propriva     47.241175
# Ramicane    -22.320900
# Stelasyn     52.085134
# Zoniferol    46.579751
# dtype: float64

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()
